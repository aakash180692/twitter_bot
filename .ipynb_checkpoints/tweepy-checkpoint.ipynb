# %%
import tweepy

# %%
consumer_key = 'bO8huqXYA9xJV5461JHQy3WLA'
consumer_secret = '9AjBzgOWqgdOqKNpU3Kg2l24ZMDl5X14ixhGw0yxbjrWTm0EN7'
access_token = '1112361052124139520-eKjK2iRZT7QIVv0fuFKVNKb7m2kDjA'
access_token_secret = 'kVkfn698wkGkgCHiQmqO5hnPlptE7QXIEwxWyj3WRbEyP'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
user = api.me()
print (user.name)
# Out:
# tweetbot

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# Hello Twitter! #myfirstTweet

# %%
# tweeting Hello world
api.update_status('Hello world')
# Out:
# Status(_api=<tweepy.api.API object at 0x7f04facecf28>, _json={'created_at': 'Sun Mar 31 15:42:49 +0000 2019', 'id': 1112379729724755969, 'id_str': '1112379729724755969', 'text': 'Hello world', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://github.com/aakash180692" rel="nofollow">tweetbot_2019</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1112361052124139520, 'id_str': '1112361052124139520', 'name': 'tweetbot', 'screen_name': 'tweetbo66082911', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 0, 'listed_count': 0, 'created_at': 'Sun Mar 31 14:28:36 +0000 2019', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_co
# ...

# %%
# tweets from a specific user
trump_tweets = api.user_timeline('realdonaldtrump',count=200, tweet_mode="extended")
for tweet in trump_tweets:
    print(tweet.full_text)
    print("/n")
# Out:
# “The Trump Administration has succeeded in dramatically raising the costs to Iran for its sinister behavior, at no cost to the U.S. or our allies. That’s the definition of a foreign-policy achievement.” Bret Stephens, @nytimes  We are getting stronger all over the world, watch!
# /n
# Mexico must use its very strong immigration laws to stop the many thousands of people trying to get into the USA. Our detention areas are maxed out &amp; we will take no more illegals. Next step is to close the Border! This will also help us with stopping the Drug flow from Mexico!
# /n
# It would be so easy to fix our weak and very stupid Democrat inspired immigration laws. In less than one hour, and then a vote, the problem would be solved. But the Dems don’t care about the crime, they don’t want any victory for Trump and the Republicans, even if good for USA!
# /n
# ...
